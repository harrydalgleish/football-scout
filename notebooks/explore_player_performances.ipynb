# %%
#Match ID variables
match_id = 3749493

# %%
import json
import pandas as pd

with open(f"/workspaces/football-scout/data/raw/events/{match_id}.json", "r") as file:
    result = json.load(file)

print(type(result))
print(len(result))
print(result[0])
# Out:
# <class 'list'>
# 3057
# {'id': 'd78142c2-54c8-48fd-8346-67ab75d01a5e', 'index': 1, 'period': 1, 'timestamp': '00:00:00.000', 'minute': 0, 'second': 0, 'type': {'id': 35, 'name': 'Starting XI'}, 'possession': 1, 'possession_team': {'id': 1, 'name': 'Arsenal'}, 'play_pattern': {'id': 1, 'name': 'Regular Play'}, 'team': {'id': 1, 'name': 'Arsenal'}, 'duration': 0.0, 'tactics': {'formation': 442, 'lineup': [{'player': {'id': 20015, 'name': 'Jens Lehmann'}, 'position': {'id': 1, 'name': 'Goalkeeper'}, 'jersey_number': 0}, {'player': {'id': 40222, 'name': 'Laureano Bisan-Etame Mayer'}, 'position': {'id': 2, 'name': 'Right Back'}, 'jersey_number': 0}, {'player': {'id': 38412, 'name': 'Kolo Habib Touré'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'jersey_number': 0}, {'player': {'id': 15637, 'name': "Sulzeer Jeremiah ''Sol' Campbell"}, 'position': {'id': 5, 'name': 'Left Center Back'}, 'jersey_number': 0}, {'player': {'id': 12529, 'name': 'Ashley Cole'}, 'position': {'id': 6, 'name': 'Left Back'}, 'jersey_number': 0}, {'player': {'id': 15515, 'name': 'Patrick Vieira'}, 'position': {'id': 9, 'name': 'Right Defensive Midfield'}, 'jersey_number': 0}, {'player': {'id': 40221, 'name': 'Gilberto Aparecido da Silva'}, 'position': {'id': 11, 'name': 'Left Defensive Midfield'}, 'jersey_number': 0}, {'player': {'id': 15754, 'name': 'Fredrik Ljungberg'}, 'position': {'id': 12, 'name': 'Right Midfield'}, 'jersey_number': 0}, {'player': {'id': 19312, 'name': 'Robert Pirès'}, 'position': {'id': 16, 'name': 'Left Midfield'}, 'jersey_number': 0}, {'player': {'id': 15512, 'name': 'Sylvain Wiltord'}, 'position': {'id': 22, 'name': 'Right Center Forward'}, 'jersey_number': 0}, {'player': {'id': 15516, 'name': 'Thierry Henry'}, 'position': {'id': 24, 'name': 'Left Center Forward'}, 'jersey_number': 0}]}}

# %%
#Code to test all events available in the code
list_of_all_events = []
for event in result:
    event_type = event["type"]["name"]
    if event_type not in list_of_all_events:
        list_of_all_events.append(event_type)
    if event_type == "Substitution":
        print(event)
print(list_of_all_events)
# Out:
# {'id': 'dd8a1e0a-f5b4-4a4a-818c-69456a01232c', 'index': 929, 'period': 1, 'timestamp': '00:30:09.342', 'minute': 30, 'second': 9, 'type': {'id': 19, 'name': 'Substitution'}, 'possession': 66, 'possession_team': {'id': 29, 'name': 'Everton'}, 'play_pattern': {'id': 1, 'name': 'Regular Play'}, 'team': {'id': 1, 'name': 'Arsenal'}, 'player': {'id': 15512, 'name': 'Sylvain Wiltord'}, 'position': {'id': 22, 'name': 'Right Center Forward'}, 'duration': 0.0, 'substitution': {'outcome': {'id': 103, 'name': 'Tactical'}, 'replacement': {'id': 15654, 'name': 'Martin Keown'}}}
# {'id': '9778e29c-b86c-4ed1-b555-ddf11614c6be', 'index': 1949, 'period': 2, 'timestamp': '00:11:33.240', 'minute': 56, 'second': 33, 'type': {'id': 19, 'name': 'Substitution'}, 'possession': 130, 'possession_team': {'id': 29, 'name': 'Everton'}, 'play_pattern': {'id': 8, 'name': 'From Keeper'}, 'team': {'id': 29, 'name': 'Everton'}, 'player': {'id': 20189, 'name': 'Tobias Linderoth'}, 'position': {'id': 13, 'name': 'Right Center Midfield'}, 'duration': 0.0, 'substitution': {'outcome': {'id': 103, 'name': 'Tactical'}, 'replacement': {'id': 3538, 'name': 'Wayne Mark Rooney'}}}
# {'id': 'eb8cf412-7166-4564-a26a-8c2d9818e97f', 'index': 2369, 'period': 2, 'timestamp': '00:21:53.581', 'minute': 66, 'second': 53, 'type': {'id': 19, 'name': 'Substitution'}, 'possession': 148, 'possession_team': {'id': 29, 'name': 'Everton'}, 'play_pattern': {'id': 1, 'name': 'Regular Play'}, 'team': {'id': 29, 'name': 'Everton'}, 'player': {'id': 40289, 'name': 'Mark Pembridge'}, 'position': {'id': 16, 'name': 'Left Midfield'}, 'duration': 0.0, 'substitution': {'outcome': {'id': 103, 'name': 'Tactical'}, 'replacement': {'id': 40282, 'name': 'Gary Naysmith'}}}
# {'id': '875ebe08-59ec-4276-9196-8ccc376c0fa5', 'index': 2370, 'period': 2, 'timestamp': '00:22:07.646', 'minute': 67, 'second': 7, 'type': {'id': 19, 'name': 'Substitution'}, 'possession': 148, 'possession_team': {'id': 29, 'name': 'Everton'}, 'play_pattern': {'id': 1, 'name': 'Regular Play'}, 'team': {'id': 29, 'name': 'Everton'}, 'player': {'id': 40281, 'name': 'David Unsworth'}, 'position': {'id': 6, 'name': 'Left Back'}, 'duration': 0.0, 'substitution': {'outcome': {'id': 103, 'name': 'Tactical'}, 'replacement': {'id': 40287, 'name': 'Tie Li'}}}
# {'id': '50c237a3-a4f0-4725-80dc-0b5477bd8a96', 'index': 2428, 'period': 2, 'timestamp': '00:24:47.762', 'minute': 69, 'second': 47, 'type': {'id': 19, 'name': 'Substitution'}, 'possession': 154, 'possession_team': {'id': 29, 'name': 'Everton'}, 'play_pattern': {'id': 3, 'name': 'From Free Kick'}, 'team': {'id': 1, 'name': 'Arsenal'}, 'player': {'id': 19312, 'name': 'Robert Pirès'}, 'position': {'id': 16, 'name': 'Left Midfield'}, 'duration': 0.0, 'substitution': {'outcome': {'id': 103, 'name': 'Tactical'}, 'replacement': {'id': 24972, 'name': 'Ray Parlour'}}}
# ['Starting XI', 'Half Start', 'Pass', 'Ball Receipt*', 'Carry', 'Pressure', 'Duel', 'Ball Recovery', 'Clearance', 'Block', 'Miscontrol', 'Dribbled Past', 'Dribble', 'Foul Committed', 'Foul Won', 'Interception', 'Dispossessed', 'Shot', 'Goal Keeper', 'Injury Stoppage', 'Player Off', 'Player On', 'Shield', 'Tactical Shift', 'Substitution', 'Half End']

# %% [markdown]
# Used the above code to print off all events recorded in a game. Will then use this to define statistics throughout the game.
# For shots. ["name"] is used to record the string from the below data
# outcome -  tells whether the shot is on/off target or a goal.
# body_part - tells of the body part used to take the shot
# statsbomb_xg - tells of the xG of the goal

# %%
#Code for adding all shot data to each player
players = {}
for i in [0,1]:
    tactic = result[i]["tactics"]
    for dictionary in tactic["lineup"]:
        players[(dictionary['player']['id'])] = {'name':(dictionary['player']['name']),
                                                 'position':dictionary['position']['name'],
                                                 'minutes':0,
                                                 'goals':0,
                                                 'assists':0,
                                                 'yellow_cards':0,
                                                 'red_cards':0,
                                                 'shots':0,
                                                 'shots_on_target':0,
                                                 'xG':0,
                                                 'passes':0,
                                                 'successful_passes':0,
                                                 'ground_pass':0,
                                                 'high_pass':0,
                                                 'low_pass':0,
                                                 'cross':0,
                                                 'successful_crosses':0,
                                                 'fouls_commited':0,
                                                 'fouls_won':0,
                                                 'saves':0,
                                                 'dribble':0,
                                                 'successful_dribble':0,
                                                 'times_dispossed':0,
                                                 'interceptions':0,
                                                 'tackles':0,
                                                 'succesful_tackles':0,
                                                 'block': 0,
                                                 'clearance': 0
                                                 }

# %%
print(players)
# Out:
# {20015: {'name': 'Jens Lehmann', 'position': 'Goalkeeper', 'goals': 0, 'assists': 0, 'yellow_cards': 0, 'red_cards': 0, 'shots': 0, 'shots_on_target': 0, 'xG': 0, 'passes': 0, 'successful_passes': 0, 'ground_pass': 0, 'high_pass': 0, 'low_pass': 0, 'cross': 0, 'successful_crosses': 0, 'fouls_commited': 0, 'fouls_won': 0, 'saves': 0, 'dribble': 0, 'successful_dribble': 0, 'times_dispossed': 0, 'interceptions': 0, 'tackles': 0, 'succesful_tackles': 0, 'block': 0, 'clearance': 0}, 40222: {'name': 'Laureano Bisan-Etame Mayer', 'position': 'Right Back', 'goals': 0, 'assists': 0, 'yellow_cards': 0, 'red_cards': 0, 'shots': 0, 'shots_on_target': 0, 'xG': 0, 'passes': 0, 'successful_passes': 0, 'ground_pass': 0, 'high_pass': 0, 'low_pass': 0, 'cross': 0, 'successful_crosses': 0, 'fouls_commited': 0, 'fouls_won': 0, 'saves': 0, 'dribble': 0, 'successful_dribble': 0, 'times_dispossed': 0, 'interceptions': 0, 'tackles': 0, 'succesful_tackles': 0, 'block': 0, 'clearance': 0}, 38412: {'name': 'Kolo Habib Touré', 'position': 'Right Center Back', 'goals': 0, 'assists': 0, 'yellow_cards': 0, 'red_cards': 0, 'shots': 0, 'shots_on_target': 0, 'xG': 0, 'passes': 0, 'successful_passes': 0, 'ground_pass': 0, 'high_pass': 0, 'low_pass': 0, 'cross': 0, 'successful_crosses': 0, 'fouls_commited': 0, 'fouls_won': 0, 'saves': 0, 'dribble': 0, 'successful_dribble': 0, 'times_dispossed': 0, 'interceptions': 0, 'tackles': 0, 'succesful_tackles': 0, 'block': 0, 'clearance': 0}, 15637: {'name': "Sulzeer Jeremiah ''Sol' Campbell", 'position': 'Left Center Back', 'goals': 0, 'assists': 0, 'yellow_cards': 0, 'red_cards': 0, 'shots': 0, 'shots_on_target': 0, 'xG': 0, 'passes': 0, 'successful_passes': 0, 'ground_pass': 0, 'high_pass': 0, 'low_pass': 0, 'cross': 0, 'successful_crosses': 0, 'fouls_commited': 0, 'fouls_won': 0, 'saves': 0, 'dribble': 0, 'successful_dribble': 0, 'times_dispossed': 0, 'interceptions': 0, 'tackles': 0, 'succesful_tackles': 0, 'block': 0, 'clearance': 0}, 12529: {'name': 'Ashley Cole', 'position': 'Left Back', 'goals': 0, 'assists': 0, 'yellow_cards': 0, 'red_cards': 0, 'shots': 0, 'shots_on_target': 0, 'xG': 0, 'passes': 0, 'successful_passes': 0, 'ground_pass': 0, 'high_pass': 0, 'low_pass': 0, 'cross': 0, 'successful_crosses': 0, 'fouls_commited': 0, 'fouls_won': 0, 'saves': 0, 'dribble': 0, 'successful_dribble': 0, 'times_dispossed': 0, 'interceptions': 0, 'tackles': 0, 'succesful_tackles': 0, 'block': 0, 'clearance': 0}, 15515: {'name': 'Patrick Vieira', 'position': 'Right Defensive Midfield', 'goals': 0, 'assists': 0, 'yellow_cards': 0, 'red_cards': 0, 'shots': 0, 'shots_on_target': 0, 'xG': 0, 'passes': 0, 'successful_passes': 0, 'ground_pass': 0, 'high_pass': 0, 'low_pass': 0, 'cross': 0, 'successful_crosses': 0, 'fouls_commited': 0, 'fouls_won': 0, 'saves': 0, 'dribble': 0, 'successful_dribble': 0, 'times_dispossed': 0, 'interceptions': 0, 'tackles': 0, 'succesful_tackles': 0, 'block': 0, 'clearance': 0}, 40221: {'name': 'Gilberto Aparecido da Silva', 'position': 'Left Defensive Midfield', 'goals': 0, 'assists': 0, 'yellow_cards': 0, 'red_cards': 0, 'shots': 0, 'shots_on_target': 0, 'xG': 0, 'passes': 0, 'successful_passes': 0, 'ground_pass': 0, 'high_pass': 0, 'low_pass': 0, 'cross': 0, 'successful_crosses': 0, 'fouls_commited': 0, 'fouls_won': 0, 'saves': 0, 'dribble': 0, 'successful_dribble': 0, 'times_dispossed': 0, 'interceptions': 0, 'tackles': 0, 'succesful_tackles': 0, 'block': 0, 'clearance': 0}, 15754: {'name': 'Fredrik Ljungberg', 'position': 'Right Midfield', 'goals': 0, 'assists': 0, 'yellow_cards': 0, 'red_cards': 0, 'shots': 0, 'shots_on_target': 0, 'xG': 0, 'passes': 0, 'successful_passes': 0, 'ground_pass': 0, 'high_pass': 0, 'low_pass': 0, 'cross': 0, 'successful_crosses': 0, 'fouls_commited': 0, 'fouls_won': 0, 'saves': 0, 'dribble': 0, 'successful_dribble': 0, 'times_dispossed': 0, 'interceptions': 0, 'tackles': 0, 'succesful_tackles': 0, 'block': 0, 'clearance': 0}, 19312: {'name': 'Robert Pirès', 'position ...

# %% [markdown]
# I've now created a dictionary that stores all the players id's and linked their statistics for the game all set to 0.

# %%
notable_events = ['Pass', 'Duel', 'Block', 'Clearance','Dribble','Dribbled Past','Foul Committed', 'Foul Won','Interception','Shot','Goal Keeper','Substitution']
for event in result:
    event_type = event["type"]["name"]
    if event_type in notable_events:
        if event_type == "Substitution":
            players[(event['replacement']['id'])] = {'name':(event['replacement']['name']),
                                                 'position':event['position']['name'], #Question Here
                                                 'minutes':0,
                                                 'goals':0,
                                                 'assists':0,
                                                 'yellow_cards':0,
                                                 'red_cards':0,
                                                 'shots':0,
                                                 'shots_on_target':0,
                                                 'xG':0,
                                                 'passes':0,
                                                 'successful_passes':0,
                                                 'ground_pass':0,
                                                 'high_pass':0,
                                                 'low_pass':0,
                                                 'cross':0,
                                                 'successful_crosses':0,
                                                 'fouls_commited':0,
                                                 'fouls_won':0,
                                                 'saves':0,
                                                 'dribble':0,
                                                 'successful_dribble':0,
                                                 'times_dispossed':0,
                                                 'interceptions':0,
                                                 'tackles':0,
                                                 'succesful_tackles':0,
                                                 'block': 0,
                                                 'clearance': 0
                                                 }
            
    else:
        pass
