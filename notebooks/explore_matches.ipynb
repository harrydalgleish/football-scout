# %%
#Competition and Season ID variables
competition_id = 2
season_id = 44

# %%
import json
import pandas as pd

with open(f"/workspaces/football-scout/data/raw/matches/{competition_id}_{season_id}.json", "r") as file:
    matches = json.load(file)

print(type(matches))
print(len(matches))
print(matches[0])
# Out:
# <class 'list'>
# 38
# ...

# %%
df = pd.DataFrame(matches)
#print(df.head())
print(df[df["match_id"] == 3749603])
# Out:
#    match_id  match_date      kick_off  \
# 4   3749603  2004-05-09  14:05:00.000
#
#                                          competition  \
# 4  {'competition_id': 2, 'country_name': 'England...
#
#                                           season  \
# 4  {'season_id': 44, 'season_name': '2003/2004'}
#
#                                            home_team  \
# 4  {'home_team_id': 55, 'home_team_name': 'Fulham...
#
#                                            away_team  home_score  away_score  \
# 4  {'away_team_id': 1, 'away_team_name': 'Arsenal...           0           1
#
#   match_status match_status_360                last_updated  \
# 4    available        scheduled  2025-06-24T09:42:29.802608
#
#           last_updated_360                                           metadata  \
# 4  2021-06-13T16:17:31.694  {'data_version': '1.1.0', 'shot_fidelity_versi...
#
#    match_week                    competition_stage  \
# 4           2  {'id': 1, 'name': 'Regular Season'}
#
# ...
